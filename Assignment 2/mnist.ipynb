# %%
import os
import numpy as np
import pandas as pd
import time
import tensorflow as tf
from tqdm import tqdm
import tensorflow_datasets.public_api as tfds
from matplotlib import pyplot as plt
from sklearn import metrics, model_selection, preprocessing
np.random.seed(597)
tf.random.set_seed(597)
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
# MNIST
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
# Split validation set
X_train, X_val, y_train, y_val = model_selection.train_test_split(X_train, y_train, test_size=10000, random_state=597)
X_train = tf.reshape(X_train, (50000, 784))
X_val = tf.reshape(X_val, (10000, 784))
X_test = tf.reshape(X_test, (10000, 784))
assert X_train.shape == (50000, 784)
assert X_val.shape == (10000, 784)
assert X_test.shape == (10000, 784)
assert y_train.shape == (50000,)
assert y_val.shape == (10000,)
assert y_test.shape == (10000,)

# %%
# Take a look at the first digit
print(y_train[0])
plt.imshow(tf.reshape(X_train[0], (28, 28)))
# Out:
# 4

# %%
size_input = 784
size_hidden1 = 300
size_hidden2 = 100
size_output = 10
number_of_train_examples = 50000
number_of_val_examples = 10000
number_of_test_examples = 10000

# Split dataset into batches
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(20)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(10)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(10)

# %%
# Define class to build mlp model
class MLP(object):
  def __init__(self, size_input, size_hidden1, size_hidden2, size_output, lr=1e-3, reg=None, dropout=None, normal=False):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of hidden layer1
    size_hidden2: int, size of hidden layer2
    size_output: int, size of output layer
    lr: float, learning rate for optimizer
    reg: list, penalty. e.g. ['l1']
    dropout: float, dropout rate
    normal: bool, whether normalize the data
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_output, self.lr, self.reg, self.dropout, self.normal =\
    size_input, size_hidden1, size_hidden2, size_output, lr, reg, dropout, normal
    
    # Initialize weights between input layer and hidden layer 1
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1]))
    # Initialize biases for hidden layer 1
    self.b1 = tf.Variable(tf.random.normal([1, self.size_hidden1]))
    # Initialize weights between hidden layer 1 and hidden layer 2
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2]))
    # Initialize biases for hidden layer 2
    self.b2 = tf.Variable(tf.random.normal([1, self.size_hidden2]))
     # Initialize weights between hidden layer 2 and output layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_output]))
    # Initialize biases for output layer
    self.b3 = tf.Variable(tf.random.normal([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.b1, self.b2, self.b3]
    
  def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    Always use gpu
    """
    with tf.device('gpu:0'):
        self.y = self.compute_output(X)
        
    return self.y
  
  def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    y_true_tf = tf.cast(y_true, dtype=tf.int32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    # Use softmax categorical cross entropy for classification task
    loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)(y_true_tf, y_pred_tf)
    if self.reg != None:
        if self.reg == ['l1']:
            loss = loss + 1e-5*(tf.reduce_sum([tf.reduce_sum(tf.abs(var)) for var in self.variables]))
        elif self.reg == ['l2']:
            loss = loss + 1e-5*(tf.reduce_sum([tf.nn.l2_loss(var) for var in self.variables]))
        elif self.reg == ['l1', 'l2']:
            loss = loss + 1e-5*(tf.reduce_sum([tf.reduce_sum(tf.abs(var)) for var in self.variables])) +\
                          1e-5*(tf.reduce_sum([tf.nn.l2_loss(var) for var in self.variables]))
        else:
            assert 1==0, "The parameters of regularization is unknown, please use ['l1'] or ['l1', 'l2']"
    # Add l1 reg
    return  loss 
  
  def backward(self, X_train, y_train):
    """
    backward pass
    """
    optimizer = tf.keras.optimizers.Adam(learning_rate=self.lr)
    with tf.GradientTape() as tape:
        predicted = self.forward(X_train)
        current_loss = self.loss(predicted, y_train) 
    grads = tape.gradient(current_loss, self.variables)
    optimizer.apply_gradients(zip(grads, self.variables))
        
        
  def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    # Normalize dataset before moving forward
    if self.normal:   
        X_tf = X_tf/255
    # Add dropout
    if self.dropout != None:     
        X_tf = tf.nn.dropout(X_tf, rate = self.dropout, seed = 597)
    # Compute values in hidden layer 1
    what1 = tf.matmul(X_tf, self.W1) + self.b1
    hhat1 = tf.nn.relu(what1)
    # Compute values in hidden layer 2
    what2 = tf.matmul(hhat1, self.W2) + self.b2
    hhat2 = tf.nn.relu(what2)
    # Compute output
    output = tf.matmul(hhat2, self.W3) + self.b3
    # softmax is applied in the calculation of cross entropy
    return output

# %%
def train(trail):
    # Set number of epochs
    NUM_EPOCHS = 10
    # Set random seed
    np.random.seed(trail*597)
    tf.random.set_seed(trail*597)
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
    X_train, X_val, y_train, y_val = model_selection.train_test_split(X_train, y_train, test_size=10000, random_state=trail*597)
    X_train = tf.reshape(X_train, (50000, 784))
    X_val = tf.reshape(X_val, (10000, 784))
    X_test = tf.reshape(X_test, (10000, 784))
    # Initialize model using GPU
    mlp = MLP(size_input, size_hidden1, size_hidden2, size_output, lr=0.001, normal=True, reg=['l2'])#, dropout=0.1)

    time_start = time.time()
    training_df = pd.DataFrame(columns = ['epoch', 'train_loss', 'train_accuracy', 'test_loss', 'test_accuracy'])
    for epoch in range(NUM_EPOCHS):
        loss_total = tf.zeros([1,1], dtype=tf.float32)
        lt = 0
        acc = []
        train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(trail*597)).batch(20)
        for inputs, outputs in (train_ds):
            preds = mlp.forward(inputs)
            loss_total = loss_total + mlp.loss(preds, outputs)
            lt = lt + mlp.loss(preds, outputs)
            acc.append(tf.keras.metrics.sparse_categorical_accuracy(outputs, preds))
            mlp.backward(inputs, outputs)
        avg_loss = np.sum(loss_total) / X_train.shape[0]
        avg_acc = np.mean(acc)
        training_df.loc[epoch, ['epoch', 'train_loss', 'train_accuracy']] = [epoch + 1, avg_loss, avg_acc]
        print('Number of Epoch = {} - Average cross entropy:= {:.4f}'.format(epoch + 1, avg_loss),
              '\n                    - Average accuracy:= {:.4f}'.format(avg_acc))
        # validation for each epoch
        val_loss_total = tf.Variable(0, dtype=tf.float32)
        val_acc = []
        for inputs, outputs in val_ds:
            preds = mlp.forward(inputs)
            val_loss_total = val_loss_total + mlp.loss(preds, outputs)
            val_acc.append(tf.keras.metrics.sparse_categorical_accuracy(outputs, preds))
        val_avg_loss = np.sum(val_loss_total) / X_val.shape[0]
        val_avg_acc = np.mean(val_acc)
        training_df.loc[epoch, ['val_loss', 'val_accuracy']] = [val_avg_loss, val_avg_acc]

    time_taken = time.time() - time_start

    print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
    
    return mlp

# %%
mlp = train(1)

# %%
# Plot train validation error
f = plt.figure(figsize=(20, 10))
ax1 = f.add_subplot(121, xlabel = 'epoch', ylabel = 'accuracy')
ax2 = f.add_subplot(122, xlabel = 'epoch', ylabel = 'loss')
ax1.plot(training_df['epoch'], training_df['train_accuracy'], label = 'train')
ax1.plot(training_df['epoch'], training_df['val_accuracy'], label = 'val')
ax1.legend()
ax2.plot(training_df['epoch'], training_df['train_loss'], label = 'train')
ax2.plot(training_df['epoch'], training_df['val_loss'], label = 'val')
ax2.legend()

# %%
# Validation
val_loss_total = tf.Variable(0, dtype=tf.float32)
val_acc = []
for inputs, outputs in val_ds:
    preds = mlp.forward(inputs)
    val_loss_total = val_loss_total + mlp.loss(preds, outputs)
    val_acc.append(tf.keras.metrics.sparse_categorical_accuracy(outputs, preds))
val_avg_loss = np.sum(val_loss_total) / X_val.shape[0]
val_avg_acc = np.mean(val_acc)
print('Validation cross entropy: {:.4f}'.format(val_avg_loss),
      '\nTest accuracy:= {:.4f}'.format(val_avg_acc))

# %%
# Run the whole process 10 times
testing_df = pd.DataFrame(columns = ['trail', 'accuracy', 'loss'])
for trail in range(10):
    mlp = train(trail+1)
    test_loss_total = tf.Variable(0, dtype=tf.float32)
    test_acc = []
    test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).shuffle(25, seed=trail*(597)).batch(10)
    for inputs, outputs in test_ds:
        preds = mlp.forward(inputs)
        test_loss_total = test_loss_total + mlp.loss(preds, outputs)
        test_acc.append(tf.keras.metrics.sparse_categorical_accuracy(outputs, preds))
    test_avg_loss = np.sum(test_loss_total) / X_test.shape[0]
    test_avg_acc = np.mean(test_acc)
    testing_df.loc[trail] = [trail+1, test_avg_acc, test_avg_loss]
    print('Test cross entropy: {:.4f}'.format(test_avg_loss),
          '\nTest accuracy:= {:.4f}'.format(test_avg_acc))
# Out:
# Number of Epoch = 1 - Average cross entropy:= 2.7828
#                     - Average accuracy:= 0.7629
# Number of Epoch = 2 - Average cross entropy:= 0.1257
#                     - Average accuracy:= 0.8636
# Number of Epoch = 3 - Average cross entropy:= 0.0436
#                     - Average accuracy:= 0.8915
# Number of Epoch = 4 - Average cross entropy:= 0.0316
#                     - Average accuracy:= 0.9051
# Number of Epoch = 5 - Average cross entropy:= 0.0292
#                     - Average accuracy:= 0.9111
# Number of Epoch = 6 - Average cross entropy:= 0.0273
#                     - Average accuracy:= 0.9128
# Number of Epoch = 7 - Average cross entropy:= 0.0277
#                     - Average accuracy:= 0.9121
# Number of Epoch = 8 - Average cross entropy:= 0.0270
#                     - Average accuracy:= 0.9140
# Number of Epoch = 9 - Average cross entropy:= 0.0267
#                     - Average accuracy:= 0.9138
# Number of Epoch = 10 - Average cross entropy:= 0.0278
#                     - Average accuracy:= 0.9138
#
# Total time taken (in seconds): 604.16
# Test cross entropy: 0.0390
# Test accuracy:= 0.9360
# Number of Epoch = 1 - Average cross entropy:= 2.4570
#                     - Average accuracy:= 0.7781
# Number of Epoch = 2 - Average cross entropy:= 0.1002
#                     - Average accuracy:= 0.8738
# Number of Epoch = 3 - Average cross entropy:= 0.0341
#                     - Average accuracy:= 0.9025
# Number of Epoch = 4 - Average cross entropy:= 0.0306
#                     - Average accuracy:= 0.9078
# Number of Epoch = 5 - Average cross entropy:= 0.0296
#                     - Average accuracy:= 0.9101
# Number of Epoch = 6 - Average cross entropy:= 0.0302
#                     - Average accuracy:= 0.9094
# Number of Epoch = 7 - Average cross entropy:= 0.0301
#                     - Average accuracy:= 0.9099
# Number of Epoch = 8 - Average cross entropy:= 0.0292
#                     - Average accuracy:= 0.9116
# Number of Epoch = 9 - Average cross entropy:= 0.0279
#                     - Average accuracy:= 0.9145
# Number of Epoch = 10 - Average cross entropy:= 0.0278
#                     - Average accuracy:= 0.9133
#
# Total time taken (in seconds): 600.12
# Test cross entropy: 0.1361
# Test accuracy:= 0.8276
# Number of Epoch = 1 - Average cross entropy:= 2.1486
#                     - Average accuracy:= 0.7819
# Number of Epoch = 2 - Average cross entropy:= 0.1047
#                     - Average accuracy:= 0.8701
# Number of Epoch = 3 - Average cross entropy:= 0.0364
#                     - Average accuracy:= 0.9009
# Number of Epoch = 4 - Average cross entropy:= 0.0305
#                     - Average accuracy:= 0.9069
# Number of Epoch = 5 - Average cross entropy:= 0.0300
#                     - Average accuracy:= 0.9084
# Number of Epoch = 6 - Average cross entropy:= 0.0302
#                     - Average accuracy:= 0.9102
# Number of Epoch = 7 - Average cross entropy:= 0.0299
#                     - Average accuracy:= 0.9118
# Number of Epoch = 8 - Average cross entropy:= 0.0291
#                     - Average accuracy:= 0.9132
# Number of Epoch = 9 - Average cross entropy:= 0.0286
#                     - Average accuracy:= 0.9140
# Number of Epoch = 10 - Average cross entropy:= 0.0274
#                     - Average accuracy:= 0.9141
#
# Total time taken (in seconds): 632.39
# Test cross entropy: 0.0558
# Test accuracy:= 0.9047
# Number of Epoch = 1 - Average cross entropy:= 2.4443
#                     - Average accuracy:= 0.7732
# Number of Epoch = 2 - Average cross entropy:= 0.1267
#                     - Average accuracy:= 0.8689
# Number of Epoch = 3 - Average cross entropy:= 0.0422
#                     - Average accuracy:= 0.8948
# Number of Epoch = 4 - Average cross entropy:= 0.0311
#                     - Average accuracy:= 0.9065
# Number of Epoch = 5 - Average cross entropy:= 0.0272
#                     - Average accuracy:= 0.9146
# Number of Epoch = 6 - Average cross entropy:= 0.0271
#                     - Average accuracy:= 0.9162
# Number of Epoch = 7 - Average cross entropy:= 0.0270
#                     - Average accuracy:= 0.9137
# Number of Epoch = 8 - Average cross entropy:= 0.0280
#                     - Average accuracy:= 0.9112
# Number of Epoch = 9 - Average cross entropy:= 0.0311
#                     - Average accuracy:= 0.9066
# Number of Epoch = 10 - Average cross entropy:= 0.0331
#                     - Average accuracy:= 0.9016
#
# Total time taken (in seconds): 633.09
# Test cross entropy: 0.0532
# Test accuracy:= 0.9087
# Number of Epoch = 1 - Average cross entropy:= 2.7723
#                     - Average accuracy:= 0.7728
# Number of Epoch = 2 - Average cross entropy:= 0.1504
#                     - Average accuracy:= 0.8622
# Number of Epoch = 3 - Average cross entropy:= 0.0505
#                     - Average accuracy:= 0.8878
# Number of Epoch = 4 - Average cross entropy:= 0.0347
#                     - Average accuracy:= 0.9026
# Number of Epoch = 5 - Average cross entropy:= 0.0280
#                     - Average accuracy:= 0.9139
# Number of Epoch = 6 - Average cross entropy:= 0.0269
#                     - Average accuracy:= 0.9153
# Number of Epoch = 7 - Average cross entropy:= 0.0268
#                     - Average accuracy:= 0.9161
# Number of Epoch = 8 - Average cross entropy:= 0.0264
#                     - Average accuracy:= 0.9154
# Number of Epoch = 9 - Average cross entropy:= 0.0255
#                     - Average accuracy:= 0.9200
# Number of Epoch = 10 - Average cross entropy:= 0.0244
#                     - Average accuracy:= 0.9201
#
# Total time taken (in seconds): 600.69
# Test cross entropy: 0.0564
# Test accuracy:= 0.9068
# Number of Epoch = 1 - Average cross entropy:= 2.6957
#                     - Average accuracy:= 0.7646
# Number of Epoch = 2 - Average cross entropy:= 0.0746
#                     - Average accuracy:= 0.8785
# Number of Epoch = 3 - Average cross entropy:= 0.0344
#                     - Average accuracy:= 0.9037
# Number of Epoch = 4 - Average cross entropy:= 0.0305
#                     - Average accuracy:= 0.9080
# Number of Epoch = 5 - Average cross entropy:= 0.0290
#                     - Average accuracy:= 0.9125
# Number of Epoch = 6 - Average cross entropy:= 0.0273
#                     - Average accuracy:= 0.9138
# Number of Epoch = 7 - Average cross entropy:= 0.0276
#                     - Average accuracy:= 0.9135
# Number of Epoch = 8 - Average cross entropy:= 0.0268
#                     - Average accuracy:= 0.9164
# Number of Epoch = 9 - Average cross entropy:= 0.0259
#                     - Average accuracy:= 0.9170
# Number of Epoch = 10 - Average cross entropy:= 0.0258
#                     - Average accuracy:= 0.9189
#
# Total time taken (in seconds): 603.58
# Test cross entropy: 0.1432
# Test accuracy:= 0.8315
# Number of Epoch = 1 - Average cross entropy:= 2.6406
#                     - Average accuracy:= 0.7634
# Number of Epoch = 2 - Average cross entropy:= 0.0940
#                     - Average accuracy:= 0.8719
# Number of Epoch = 3 - Average cross entropy:= 0.0353
#                     - Average accuracy:= 0.9014
# Number of Epoch = 4 - Average cross entropy:= 0.0303
#                     - Average accuracy:= 0.9083
# Number of Epoch = 5 - Average cross entropy:= 0.0267
#                     - Average accuracy:= 0.9143
# Number of Epoch = 6 - Average cross entropy:= 0.0254
#                     - Average accuracy:= 0.9173
# Number of Epoch = 7 - Average cross entropy:= 0.0244
#                     - Average accuracy:= 0.9191
# Number of Epoch = 8 - Average cross entropy:= 0.0240
#                     - Average accuracy:= 0.9199
# Number of Epoch = 9 - Average cross entropy:= 0.0231
#                     - Average accuracy:= 0.9221
# Number of Epoch = 10 - Average cross entropy:= 0.0230
#                     - Average accuracy:= 0.9216
#
# Total time taken (in seconds): 561.52
# Test cross entropy: 0.0395
# Test accuracy:= 0.9236
# Number of Epoch = 1 - Average cross entropy:= 2.3926
#                     - Average accuracy:= 0.7754
# Number of Epoch = 2 - Average cross entropy:= 0.0961
#                     - Average accuracy:= 0.8718
# Number of Epoch = 3 - Average cross entropy:= 0.0383
#                     - Average accuracy:= 0.8966
# Number of Epoch = 4 - Average cross entropy:= 0.0310
#                     - Average accuracy:= 0.9075
# Number of Epoch = 5 - Average cross entropy:= 0.0288
#                     - Average accuracy:= 0.9131
# Number of Epoch = 6 - Average cross entropy:= 0.0290
#                     - Average accuracy:= 0.9139
# Number of Epoch = 7 - Average cross entropy:= 0.0289
#                     - Average accuracy:= 0.9111
# Number of Epoch = 8 - Average cross entropy:= 0.0289
#                     - Average accuracy:= 0.9127
# Number of Epoch = 9 - Average cross entropy:= 0.0292
#                     - Average accuracy:= 0.9126
# Number of Epoch = 10 - Average cross entropy:= 0.0288
#                     - Average accuracy:= 0.9113
#
# Total time taken (in seconds): 556.18
# Test cross entropy: 0.0426
# Test accuracy:= 0.9332
# Number of Epoch = 1 - Average cross entropy:= 2.9974
#                     - Average accuracy:= 0.7743
# Number of Epoch = 2 - Average cross entropy:= 0.1765
#                     - Average accuracy:= 0.8622
# Number of Epoch = 3 - Average cross entropy:= 0.0539
#                     - Average accuracy:= 0.8894
# Number of Epoch = 4 - Average cross entropy:= 0.0371
#                     - Average accuracy:= 0.9009
# Number of Epoch = 5 - Average cross entropy:= 0.0320
#                     - Average accuracy:= 0.9060
# Number of Epoch = 6 - Average cross entropy:= 0.0293
#                     - Average accuracy:= 0.9108
# Number of Epoch = 7 - Average cross entropy:= 0.0288
#                     - Average accuracy:= 0.9131
# Number of Epoch = 8 - Average cross entropy:= 0.0294
#                     - Average accuracy:= 0.9100
# Number of Epoch = 9 - Average cross entropy:= 0.0300
#                     - Average accuracy:= 0.9092
# Number of Epoch = 10 - Average cross entropy:= 0.0298
#                     - Average accuracy:= 0.9110
#
# Total time taken (in seconds): 564.34
# Test cross entropy: 0.0452
# Test accuracy:= 0.9288
# Number of Epoch = 1 - Average cross entropy:= 2.4607
#                     - Average accuracy:= 0.7649
# Number of Epoch = 2 - Average cross entropy:= 0.1342
#                     - Average accuracy:= 0.8596
# Number of Epoch = 3 - Average cross entropy:= 0.0418
#                     - Average accuracy:= 0.8927
# Number of Epoch = 4 - Average cross entropy:= 0.0334
#                     - Average accuracy:= 0.9047
# Number of Epoch = 5 - Average cross entropy:= 0.0321
#                     - Average accuracy:= 0.9088
# Number of Epoch = 6 - Average cross entropy:= 0.0305
#                     - Average accuracy:= 0.9093
# Number of Epoch = 7 - Average cross entropy:= 0.0305
#                     - Average accuracy:= 0.9084
# Number of Epoch = 8 - Average cross entropy:= 0.0297
#                     - Average accuracy:= 0.9099
# Number of Epoch = 9 - Average cross entropy:= 0.0305
#                     - Average accuracy:= 0.9085
# Number of Epoch = 10 - Average cross entropy:= 0.0300
#                     - Average accuracy:= 0.9069
#
# Total time taken (in seconds): 548.07
# Test cross entropy: 0.0956
# Test accuracy:= 0.8662

# %%
print('average test accuracy: ', round(testing_df['accuracy'].mean(), 4))
print('accuracy standard error: ', round(np.std(testing_df['accuracy']), 4))
testing_df
# Out:
# average test accuracy:  0.8967
# accuracy standard error:  0.0386
#    trail  accuracy      loss
# 0    1.0    0.9360  0.038969
# 1    2.0    0.8276  0.136103
# 2    3.0    0.9047  0.055752
# 3    4.0    0.9087  0.053232
# 4    5.0    0.9068  0.056403
# 5    6.0    0.8315  0.143203
# 6    7.0    0.9236  0.039484
# 7    8.0    0.9332  0.042602
# 8    9.0    0.9288  0.045158
# 9   10.0    0.8662  0.095586

# %%
plt.plot(testing_df['trail'], testing_df['accuracy'])
plt.xlabel('trail')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')
